# %% [markdown]
# <a href="https://colab.research.google.com/github/Mar-SHieee/Customer-Rating-Prediction/blob/main/Copy_of_Customer_Rating_Prediction_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 1.Title & Info
#
# **Name:** Mahmoud Elaraby
# **Model:** Model 3 – Customer Rating Prediction (Regression)
# **Dataset:** Brazilian E-Commerce Public Dataset by Olist:"https://www.kaggle.com/datasets/olistbr/brazilian-ecommerce"

# %% [markdown]
# ## 2. Business Understanding
#
# ## Domain
#
# The domain of this project is **E-Commerce**.
#
# The dataset comes from Olist, which is an online marketplace. Customers can buy products from different sellers and then give a review score after receiving their orders.
#
# Customer ratings are important because they can show the customer's satisfaction with the product, delivery, and overall shopping experience.
#
# ---
#
# ## Model's Problem
#
# The problem of this model is to **predict the customer review score** for an order.
#
# The target variable is:
#
# `review_score`
#
# The review score ranges from **1 to 5**, where:
#
# - 1 = Very Low Rating
# - 2 = Low Rating
# - 3 = Average Rating
# - 4 = Good Rating
# - 5 = Excellent Rating
#
# This is a **Regression problem** because the model predicts a numerical value.
#
# The model will use information related to the order, product, payment, seller, and delivery to predict the customer rating.
#
# ---
#
# ## Why It Matters
#
# Predicting customer ratings can help an e-commerce company understand the factors that affect customer satisfaction.
#
# For example, low ratings may be related to:
#
# - Late delivery
# - Long delivery time
# - High freight cost
# - Product category
# - Seller performance
#
# By predicting ratings, the company can identify possible problems and take action before more customers have a negative experience.
#
# This can help improve:
#
# - Customer satisfaction
# - Delivery performance
# - Seller performance
# - Product quality monitoring
# - Overall customer experience
#
# ---
#
# ## Success Criteria
#
# The model will be considered successful if it can predict customer ratings with low prediction errors.
#
# The models will be evaluated using:
#
# - **MAE (Mean Absolute Error)** – lower is better.
# - **RMSE (Root Mean Squared Error)** – lower is better.
# - **R² Score** – higher is better.
#
# Four regression models will be trained and compared:
#
# 1. Linear Regression
# 2. Decision Tree Regressor
# 3. Random Forest Regressor
# 4. K-Nearest Neighbors Regressor
#
# The best model will be selected based mainly on its performance using **MAE, RMSE, and R² Score**, and then the best model will be tuned using **GridSearchCV**.

# %% [markdown]
# ## 3. Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler, OneHotEncoder, LabelEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

SEED = 42
RANDOM_STATE = SEED
np.random.seed(SEED)

import os
os.makedirs("visuals", exist_ok=True)
os.makedirs("data", exist_ok=True)
os.makedirs("model", exist_ok=True)
os.makedirs("reports", exist_ok=True)

# %% [markdown]
# ## 4. Load Data

# %%
customers = pd.read_csv("olist_customers_dataset.csv")
order_items = pd.read_csv("olist_order_items_dataset.csv")
order_payments = pd.read_csv("olist_order_payments_dataset.csv")
order_reviews = pd.read_csv("olist_order_reviews_dataset.csv")
orders = pd.read_csv("olist_orders_dataset.csv")
products = pd.read_csv("olist_products_dataset.csv")
sellers = pd.read_csv("olist_sellers_dataset.csv")
category_translation = pd.read_csv("product_category_name_translation.csv")

# Merge Orders with Customers
df = orders.merge(customers,on="customer_id",how="left")

# Merge with Order Items
df = df.merge(order_items,on="order_id",how="left")

# Merge with Products
df = df.merge(products,on="product_id",how="left")

# Merge with Sellers
df = df.merge(sellers,on="seller_id",how="left")

# Merge with Payments
df = df.merge(order_payments,on="order_id",how="left")

# Merge with Reviews
df = df.merge(order_reviews,on="order_id",how="left")

# Merge with category translation
df = df.merge(category_translation,on="product_category_name",how="left")

raw_orders = df.copy()

print('Orders:', orders.shape)
print('Customers:', customers.shape)
print('Items:', order_items.shape)
print('Payments:',order_payments.shape)
print('Products:', products.shape)
print('Sellers:', sellers.shape)
print('Reviews:', order_reviews.shape)
print('full Dataset',df.shape)
# Out:
# Orders: (99441, 8)
# Customers: (99441, 5)
# Items: (112650, 7)
# Payments: (103886, 5)
# Products: (32951, 9)
# Sellers: (3095, 4)
# Reviews: (99224, 7)
# full Dataset (119143, 40)

# %% [markdown]
# ## 5. Data Audit

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119143 entries, 0 to 119142
# Data columns (total 40 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       119143 non-null  object
#  1   customer_id                    119143 non-null  object
#  2   order_status                   119143 non-null  object
#  3   order_purchase_timestamp       119143 non-null  object
#  4   order_approved_at              118966 non-null  object
#  5   order_delivered_carrier_date   117057 non-null  object
#  6   order_delivered_customer_date  115722 non-null  object
#  7   order_estimated_delivery_date  119143 non-null  object
#  8   customer_unique_id             119143 non-null  object
#  9   customer_zip_code_prefix       119143 non-null  int64
#  10  customer_city                  119143 non-null  object
#  11  customer_state                 119143 non-null  object
# ...

# %%
df.describe(include='all').T
# Out:
#                                   count unique  \
# order_id                         119143  99441
# customer_id                      119143  99441
# order_status                     119143      8
# order_purchase_timestamp         119143  98875
# order_approved_at                118966  90733
# order_delivered_carrier_date     117057  81018
# order_delivered_customer_date    115722  95664
# order_estimated_delivery_date    119143    459
# customer_unique_id               119143  96096
# customer_zip_code_prefix       119143.0    NaN
# customer_city                    119143   4119
# customer_state                   119143     27
# order_item_id                  118310.0    NaN
# product_id                       118310  32951
# seller_id                        118310   3095
# shipping_limit_date              118310  93318
# price                          118310.0    NaN
# freight_value                  118310.0    NaN
# product_category_name            116601     73
# ...

# %%
pd.set_option('display.max_columns', None)
df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 4  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 2    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 3    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 4    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
pd.set_option('display.max_columns', None)
df.tail(10)
# Out:
#                                 order_id                       customer_id  \
# 119133  9115830be804184b91f5c00f6f49f92d  da2124f134f5dfbce9d06f29bdb6c308
# 119134  aa04ef5214580b06b10e2a378300db44  f01a6bfcc730456317e4081fe0c9940e
# 119135  aa04ef5214580b06b10e2a378300db44  f01a6bfcc730456317e4081fe0c9940e
# 119136  880675dff2150932f1601e1c07eadeeb  47cd45a6ac7b9fb16537df2ccffeb5ac
# 119137  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 119138  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 119139  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 119140  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 119141  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 119142  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#        order_status order_purchase_timestamp    order_approved_at  \
# 119133    delivered      2017-10-04 19:57:37  2017-10-04 20:07:14
# ...

# %%
missing = pd.DataFrame({
    'count': df.isna().sum(),
    'percent': df.isna().mean().mul(100).round(2)
}).sort_values('percent', ascending=False).sort_values('count', ascending=False)

print('Missing values')
missing
# Out:
# Missing values
#                                 count  percent
# review_comment_title           105154    88.26
# review_comment_message          68898    57.83
# order_delivered_customer_date    3421     2.87
# product_category_name_english    2567     2.15
# product_description_lenght       2542     2.13
# product_name_lenght              2542     2.13
# product_photos_qty               2542     2.13
# product_category_name            2542     2.13
# order_delivered_carrier_date     2086     1.75
# review_creation_date              997     0.84
# review_answer_timestamp           997     0.84
# review_id                         997     0.84
# review_score                      997     0.84
# product_weight_g                  853     0.72
# product_length_cm                 853     0.72
# product_height_cm                 853     0.72
# product_width_cm                  853     0.72
# seller_zip_code_prefix            833     0.70
# seller_id                         833     0.70
# ...

# %%
print('Exact duplicate rows:',df.duplicated().sum())
print('Duplicate Order_ID rows:',df.duplicated('order_id', keep=False).sum())
# Out:
# Exact duplicate rows: 0
# Duplicate Order_ID rows: 32649

# %% [markdown]
# ## Hidden nulls problem
# there is no hidden nulls in the data as it didn't change after the code

# %%
# Detect hidden/misleading null values
hidden_nulls = ['NA', 'N/A', 'Null', 'null', '-', '']

# Replace them with actual missing values
df= df.replace(hidden_nulls, np.nan)

print("Missing values after handling hidden nulls:")
df.isnull().sum().sort_values(ascending=False)
# Out:
# Missing values after handling hidden nulls:
# review_comment_title             105155
# review_comment_message            68903
# order_delivered_customer_date      3421
# product_category_name_english      2567
# product_description_lenght         2542
# product_name_lenght                2542
# product_photos_qty                 2542
# product_category_name              2542
# order_delivered_carrier_date       2086
# review_creation_date                997
# review_answer_timestamp             997
# review_id                           997
# review_score                        997
# product_weight_g                    853
# product_length_cm                   853
# product_height_cm                   853
# product_width_cm                    853
# seller_zip_code_prefix              833
# seller_id                           833
# seller_state                        833
# freight_value                       833
# price                               833
# ...

# %% [markdown]
# # 6. preprocessing

# %%
# Clean column names by snake_case
df.columns = (
    df.columns
    .str.strip()
    .str.lower()
    .str.replace(' ', '_')
    .str.replace('-', '_')
)

print(df.columns.tolist())
# Out:
# ['order_id', 'customer_id', 'order_status', 'order_purchase_timestamp', 'order_approved_at', 'order_delivered_carrier_date', 'order_delivered_customer_date', 'order_estimated_delivery_date', 'customer_unique_id', 'customer_zip_code_prefix', 'customer_city', 'customer_state', 'order_item_id', 'product_id', 'seller_id', 'shipping_limit_date', 'price', 'freight_value', 'product_category_name', 'product_name_lenght', 'product_description_lenght', 'product_photos_qty', 'product_weight_g', 'product_length_cm', 'product_height_cm', 'product_width_cm', 'seller_zip_code_prefix', 'seller_city', 'seller_state', 'payment_sequential', 'payment_type', 'payment_installments', 'payment_value', 'review_id', 'review_score', 'review_comment_title', 'review_comment_message', 'review_creation_date', 'review_answer_timestamp', 'product_category_name_english']

# %%
# Strip whitespace and unify casing

for col in df.select_dtypes(include='object').columns:
    df[col] = df[col].str.strip().str.lower()

# %%
# Convert date columns to datetime
date_columns = [
    "order_purchase_timestamp",
    "order_approved_at",
    "order_delivered_carrier_date",
    "order_delivered_customer_date",
    "order_estimated_delivery_date",
    "shipping_limit_date",
    "review_creation_date",
    "review_answer_timestamp"
]

for col in date_columns:
    df[col] = pd.to_datetime(df[col], errors='coerce')

# Check data types
print(df[date_columns].dtypes)
# Out:
# order_purchase_timestamp         datetime64[ns]
# order_approved_at                datetime64[ns]
# order_delivered_carrier_date     datetime64[ns]
# order_delivered_customer_date    datetime64[ns]
# order_estimated_delivery_date    datetime64[ns]
# shipping_limit_date              datetime64[ns]
# review_creation_date             datetime64[ns]
# review_answer_timestamp          datetime64[ns]
# dtype: object

# %%
# Convert numeric columns to numeric values
numeric_columns = [
    'price',
    'freight_value',
    'payment_value',
    'payment_installments',
    'payment_sequential'
]

for col in numeric_columns:
    df[col] = pd.to_numeric(df[col], errors='coerce')

# Check data types
print(df[numeric_columns].dtypes)
# Out:
# price                   float64
# freight_value           float64
# payment_value           float64
# payment_installments    float64
# payment_sequential      float64
# dtype: object

# %%
# Convert all object columns to category
categorical_columns = df.select_dtypes(include='object').columns

for col in categorical_columns:
    df[col] = df[col].astype('category')

print(df.dtypes)
# Out:
# order_id                               category
# customer_id                            category
# order_status                           category
# order_purchase_timestamp         datetime64[ns]
# order_approved_at                datetime64[ns]
# order_delivered_carrier_date     datetime64[ns]
# order_delivered_customer_date    datetime64[ns]
# order_estimated_delivery_date    datetime64[ns]
# customer_unique_id                     category
# customer_zip_code_prefix                  int64
# customer_city                          category
# customer_state                         category
# order_item_id                           float64
# product_id                             category
# seller_id                              category
# shipping_limit_date              datetime64[ns]
# price                                   float64
# freight_value                           float64
# product_category_name                  category
# product_name_lenght                     float64
# ...

# %%
# Check prices and quantity that are less than 0
print("Prices < 0:")
print((df['price'] < 0).sum())
#it is zero so nothing will change
# Out:
# Prices < 0:
# 0

# %%
# Detect discount scale: 0-1 or 0-100

if 'discount' in df.columns:

    discount_max = df['discount'].max()

    print("Maximum discount value:", discount_max)

    if discount_max <= 1:
        print("Discount scale detected: 0-1")

    elif discount_max <= 100:
        print("Discount scale detected: 0-100")

    else:
        print("Warning: Discount values are outside the expected range.")

# Standardize discount to 0-1 scale

if 'discount' in df.columns:

    if df['discount'].max() > 1:
        df['discount'] = df['discount'] / 100

    print(df['discount'].describe())

# %%
# Handle missing values

#1.drop the rows with missing values in the review_score column

print(df['review_score'].isnull().sum())
df = df.dropna(subset=['review_score'])
print(df['review_score'].isnull().sum())

# 2. Categorical columns → "Unknown"
categorical_columns = df.select_dtypes(include=['object', 'category']).columns

for col in categorical_columns:
    if df[col].isna().any():
        if df[col].dtype.name == 'category':
            df[col] = df[col].cat.add_categories(['Unknown'])

        df[col] = df[col].fillna('Unknown')


# 3. Numeric columns → median
numeric_columns = df.select_dtypes(include=['int64', 'float64']).columns

for col in numeric_columns:
  median_value = df[col].median()
  df[col] = df[col].fillna(median_value)
# Out:
# 997
# 0

# %%
# Check missing values after handling
print("Missing values after handling:")
print(df.isnull().sum().sum())
# Out:
# Missing values after handling:
# 6319

# %%
missing = pd.DataFrame({
    'count': df.isna().sum(),
    'percent': df.isna().mean().mul(100).round(2)
}).sort_values('percent', ascending=False).sort_values('count', ascending=False)

print('Missing values after handling')
missing
# Out:
# Missing values after handling
#                                count  percent
# order_delivered_customer_date   3285     2.78
# order_delivered_carrier_date    2048     1.73
# shipping_limit_date              814     0.69
# order_approved_at                172     0.15
# order_purchase_timestamp           0     0.00
# order_status                       0     0.00
# customer_id                        0     0.00
# order_id                           0     0.00
# order_estimated_delivery_date      0     0.00
# customer_unique_id                 0     0.00
# customer_city                      0     0.00
# customer_zip_code_prefix           0     0.00
# customer_state                     0     0.00
# order_item_id                      0     0.00
# product_id                         0     0.00
# seller_id                          0     0.00
# price                              0     0.00
# freight_value                      0     0.00
# product_category_name              0     0.00
# ...

# %%
date_columns = [
    "order_purchase_timestamp",
    "order_approved_at",
    "order_delivered_carrier_date",
    "order_delivered_customer_date",
    "order_estimated_delivery_date",
    "shipping_limit_date",
    "review_creation_date",
    "review_answer_timestamp"
]

for col in date_columns:
    df[col] =df[col] = df[col].fillna('Unknown')

print(df.isnull().sum().sum())
# Out:
# 0

# %%
numeric_columns = [
     'price',
    'freight_value',
    'payment_value',
    'payment_installments',
    'payment_sequential'
]
for col in numeric_columns:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1

        lower = Q1 - 1.5 * IQR
        upper = Q3 + 1.5 * IQR

        outliers = ((df[col] < lower) | (df[col] > upper)).sum()

        print(f'{col}')
        print(f'Lower limit: {lower:.2f}')
        print(f'Upper limit: {upper:.2f}')
        print(f'Number of outliers: {outliers}')
        print()

#Outlier treatment: Numerical variables were checked using the IQR method. Extreme values were not automatically removed because high prices and
# freight values can represent legitimate e-commerce transactions. Only clearly invalid values, such as non-positive prices, were removed.
# Out:
# price
# Lower limit: -99.39
# Upper limit: 272.05
# Number of outliers: 8893
#
# freight_value
# Lower limit: 0.98
# Upper limit: 33.25
# Number of outliers: 12685
#
# payment_value
# Lower limit: -131.68
# Upper limit: 381.41
# Number of outliers: 9540
#
# payment_installments
# Lower limit: -3.50
# Upper limit: 8.50
# Number of outliers: 8050
#
# payment_sequential
# Lower limit: 1.00
# Upper limit: 1.00
# Number of outliers: 5104

# %% [markdown]
# # 7. Feature Engeneering

# %%
df["review_score"].value_counts()
# Out:
# review_score
# 5.0    66343
# 4.0    22319
# 1.0    15428
# 3.0     9894
# 2.0     4162
# Name: count, dtype: int64

# %% [markdown]
# # 📅 Date-Based Feature Engineering
#
# To improve the model's ability to predict customer ratings, several time-related features were extracted from the original timestamp columns. These features help capture customer behavior, delivery performance, and seasonal patterns.
#
# ## Order Lifecycle & Timestamps
#
# ```text
# [Customer places order]
#        │
#        ▼
# order_purchase_timestamp
#        │
#        ▼
# [Store approves order]
#        │
#        ▼
# order_approved_at
#        │
#        ▼
# [Seller hands package to carrier]
#        │
#        ▼
# order_delivered_carrier_date
#        │
#        ▼
# [Carrier delivers package to customer]
#        │
#        ▼
# order_delivered_customer_date
#        │
#        ▼
# [Expected delivery date target]
#        │
#        ▼
# order_estimated_delivery_date

# %% [markdown]
# ## **delivery_days = actual_delivery_date - purchase_date**
# The total number of days between the purchase date and the actual delivery date,
# This feature measures how long customers had to wait to receive their orders.

# %%
df["order_purchase_timestamp"] = pd.to_datetime(df["order_purchase_timestamp"], errors="coerce")
df["order_delivered_customer_date"] = pd.to_datetime(df["order_delivered_customer_date"], errors="coerce")

df["delivery_days"] = (
    df["order_delivered_customer_date"]
    - df["order_purchase_timestamp"]
).dt.days

# %% [markdown]
# ## **expected_delivery_days = estimated_delivery_date - purchase_date**
# The number of days the company originally expected the delivery process to take,
# This feature represents the company's promised delivery time.

# %%
df["expected_delivery_days"] = (
    df["order_estimated_delivery_date"]
    - df["order_purchase_timestamp"]
).dt.days

# %% [markdown]
# ## **delivery_delay_days = actual_delivery_days - expected_delivery_days**
# The difference between the actual delivery time and the expected delivery time,
# This feature directly measures delivery performance.

# %%
df["delivery_delay_days"] = (
    df["delivery_days"]
    - df["expected_delivery_days"]
)

# %% [markdown]
# ## **is_delayed: A binary feature that indicates whether an order was delivered late**
# This feature simplifies delivery performance into a yes/no variable.

# %%
df["is_delayed"] = (df["delivery_delay_days"] > 0).astype(int)

# %%
df["is_delayed"].value_counts()
# Out:
# is_delayed
# 0    109875
# 1      8271
# Name: count, dtype: int64

# %% [markdown]
# ## Delayed orders received an average rating of 2.50, compared with 4.14 for on-time orders. This suggests that delivery performance is one of the strongest factors affecting customer satisfaction.

# %%
df.groupby("is_delayed")["review_score"].mean()
# Out:
# is_delayed
# 0    4.133943
# 1    2.443235
# Name: review_score, dtype: float64

# %% [markdown]
# ## **The month when the order was placed.**
# Customer satisfaction may be influenced by seasonal trends.

# %%
df["purchase_month"] = (
    df["order_purchase_timestamp"]
    .dt.month
)

# %% [markdown]
# ## 0	Monday
# ## 1	Tuesday
# ## 2	Wednesday
# ## 3	Thursday
# ## 4	Friday
# ## 5	Saturday
# ## 6	Sunday

# %%
df["purchase_weekday"] = (
    df["order_purchase_timestamp"]
    .dt.dayofweek
)

# %% [markdown]
# ## **The hour when the customer placed the order**

# %%
df["purchase_hour"] = (
    df["order_purchase_timestamp"]
    .dt.hour
)

# %% [markdown]
# ## **A binary feature that indicates whether the order was placed during the weekend**

# %%
df["is_weekend"] = (
    df["purchase_weekday"]
    .isin([5, 6])
    .astype(int)
)

# %% [markdown]
# ## The day of the week had little effect on customer ratings. Average ratings remained relatively stable across all days, suggesting that purchase timing was not a significant factor affecting customer satisfaction.

# %%
weekday_names = {
    0: "Monday",
    1: "Tuesday",
    2: "Wednesday",
    3: "Thursday",
    4: "Friday",
    5: "Saturday",
    6: "Sunday"
}

(
    df.groupby("purchase_weekday")["review_score"]
    .mean()
    .rename(index=weekday_names)
    .sort_index()
)
# Out:
# purchase_weekday
# Friday       3.961794
# Monday       4.038929
# Saturday     3.998825
# Sunday       4.015065
# Thursday     3.996158
# Tuesday      4.033363
# Wednesday    4.052686
# Name: review_score, dtype: float64

# %% [markdown]
# ## Description
#
# The quarter of the year when the order was placed.
#
# ### Values
#
# | Quarter | Months |
# | :--- | :--- |
# | **Q1** | January – March |
# | **Q2** | April – June |
# | **Q3** | July – September |
# | **Q4** | October – December |
#
# ### Business Meaning
#
# This feature captures seasonal patterns that may affect customer satisfaction.

# %%
df["purchase_quarter"] = (
    df["order_purchase_timestamp"]
    .dt.quarter
)

# %% [markdown]
# ## Customer ratings varied across different quarters of the year. Orders placed during the third quarter (Q3) received the highest average rating (4.18), while orders placed during the first quarter (Q1) received the lowest average rating (3.85). This suggests that seasonal factors may influence customer satisfaction.

# %%
df.groupby("purchase_quarter")["review_score"].mean()
# Out:
# purchase_quarter
# 1    3.837516
# 2    4.111436
# 3    4.171799
# 4    3.902695
# Name: review_score, dtype: float64

# %% [markdown]
# ## Delivery status has a significant impact on customer ratings. Successfully delivered orders received an average rating of 4.09, while orders with operational issues received much lower ratings. For example, processing orders had an average rating of 1.41, unavailable orders had 1.59, and canceled orders had 1.91.

# %%
df.groupby("order_status")["review_score"].mean()
# Out:
# /tmp/ipykernel_1844/2827080253.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby("order_status")["review_score"].mean()
# order_status
# approved       2.000000
# canceled       1.824658
# created        2.333333
# delivered      4.080488
# invoiced       1.650538
# processing     1.348649
# shipped        1.976884
# unavailable    1.512539
# Name: review_score, dtype: float64

# %% [markdown]
# ## Approval Time (Hours)
#
# **Formula:**
# `approval_time_hours` = `order_approved_at` - `order_purchase_timestamp`
#
# ### Description
# The number of hours between placing the order and its approval.
#
# ### Business Meaning
# This feature measures how quickly the store processed and approved an order.

# %%
date_columns = [
    "order_purchase_timestamp",
    "order_approved_at",
    "order_delivered_carrier_date",
    "order_delivered_customer_date",
    "order_estimated_delivery_date"
]

for col in date_columns:
    if col in df.columns:
        df[col] = pd.to_datetime(df[col], errors="coerce")

print(df[date_columns].dtypes)
# Out:
# order_purchase_timestamp         datetime64[ns]
# order_approved_at                datetime64[ns]
# order_delivered_carrier_date     datetime64[ns]
# order_delivered_customer_date    datetime64[ns]
# order_estimated_delivery_date    datetime64[ns]
# dtype: object

# %%
df["approval_time_hours"] = (
    df["order_approved_at"]
    - df["order_purchase_timestamp"]
).dt.total_seconds() / 3600

# %% [markdown]
# ## Shipping Preparation Time (Hours)
#
# **Formula:**
# `shipping_preparation_hours` = `order_delivered_carrier_date` - `order_approved_at`
#
# ### Description
# The number of hours between order approval and handing the package over to the shipping carrier.
#
# ### Business Meaning
# This feature measures the efficiency and speed of fulfillment/warehouse preparation before shipping.

# %%
df["shipping_preparation_hours"] = (
    df["order_delivered_carrier_date"]
    - df["order_approved_at"]
).dt.total_seconds() / 3600

# %%
df[["approval_time_hours", "shipping_preparation_hours"]].describe()
# Out:
#        approval_time_hours  shipping_preparation_hours
# count        117974.000000               116083.000000
# mean             10.577147                   68.411702
# std              25.909426                   85.810643
# min               0.000000                -4109.256111
# 25%               0.215556                   21.278889
# 50%               0.346944                   44.336389
# 75%              15.043264                   87.500278
# max            4509.180556                 3018.301667

# %% [markdown]
# Order approval time showed almost no relationship with customer ratings (correlation = -0.026), suggesting that customers are more sensitive to the overall delivery experience than to the internal approval process.

# %%
df[["approval_time_hours", "review_score"]].corr()
# Out:
#                      approval_time_hours  review_score
# approval_time_hours             1.000000     -0.026495
# review_score                   -0.026495      1.000000

# %% [markdown]
# A negative correlation (-0.146) was observed between shipping preparation time and customer ratings. Orders that spent more time in the preparation stage tended to receive lower ratings, indicating that operational delays may negatively affect customer satisfaction.

# %%
df[["shipping_preparation_hours", "review_score"]].corr()
# Out:
#                             shipping_preparation_hours  review_score
# shipping_preparation_hours                     1.00000      -0.14858
# review_score                                  -0.14858       1.00000

# %% [markdown]
# ### Product Volume
#
# This feature represents the physical size of the product.
#
# Formula:
#
# product_volume = length × width × height
#
# Larger products may require more handling, packaging, and shipping resources, which can influence the customer experience.

# %%
df["product_volume"] = (
    df["product_length_cm"]
    * df["product_width_cm"]
    * df["product_height_cm"]
)

# %% [markdown]
# ### Product Density
#
# This feature measures the relationship between a product's weight and its volume.
#
# Formula:
#
# product_density = weight / volume
#
# This feature may help capture differences between lightweight and heavyweight products.

# %%
df["product_density"] = (
    df["product_weight_g"]
    / df["product_volume"]
)

# %% [markdown]
# Products with a larger number of images generally received higher customer ratings. Products with only one image had an average rating of 3.97, while products with 5–8 images achieved ratings above 4.15. This suggests that providing multiple product images may help customers better understand product characteristics and set more realistic expectations.

# %%
photos_review = (
    df.groupby("product_photos_qty")
    .agg(
        number_of_products=("product_id", "nunique"),
        average_rating=("review_score", "mean")
    )
    .reset_index()
)

photos_review
# Out:
#     product_photos_qty  number_of_products  average_rating
# 0                  1.0               17013        3.964594
# 1                  2.0                6230        4.053374
# 2                  3.0                3842        4.079319
# 3                  4.0                2417        4.043860
# 4                  5.0                1481        4.146197
# 5                  6.0                 961        4.061188
# 6                  7.0                 342        4.112113
# 7                  8.0                 191        4.173800
# 8                  9.0                 104        4.061489
# 9                 10.0                  95        4.002833
# 10                11.0                  46        3.835616
# 11                12.0                  35        3.883333
# 12                13.0                   9        4.500000
# 13                14.0                   5        3.666667
# 14                15.0                   8        4.500000
# ...

# %% [markdown]
# ### Shipping Price Ratio
#
# This feature measures the proportion of shipping cost relative to the product price.
#
# Formula:
#
# shipping_price_ratio = freight_value / price
#
# High shipping costs relative to product prices may negatively affect customer satisfaction.

# %%
df["shipping_price_ratio"] = (
    df["freight_value"]
    / df["price"]
)

# %% [markdown]
# ### Average Installment Value
#
# This feature represents the average amount paid in each installment.
#
# Formula:
#
# average_installment_value = payment_value / payment_installments

# %%
df["average_installment_value"] = (
    df["payment_value"]
    / df["payment_installments"]
)

# %% [markdown]
# ### Total Cost
#
# This feature represents the total amount paid by the customer, including both the product price and the shipping cost.

# %%
df["total_cost"] = (
    df["price"]
    + df["freight_value"]
)

# %% [markdown]
# ### Delivery Speed Ratio
#
# This feature compares the actual delivery time with the estimated delivery time to measure delivery efficiency.

# %%
df["delivery_speed_ratio"] = (
    df["delivery_days"]
    / df["expected_delivery_days"]
)

# %% [markdown]
# ### Review Comment Availability
#
# This feature indicates whether the customer wrote a review comment. Customers who leave written feedback may have different satisfaction patterns than those who only provide a rating.

# %%
df["has_review_comment"] = (
    df["review_comment_message"]
    .notna()
    .astype(int)
)

# %% [markdown]
# ### Multiple Product Photos
#
# This feature indicates whether a product has more than one image. Additional product images may help customers better understand the product before purchasing.

# %%
df["has_multiple_photos"] = (
    df["product_photos_qty"] > 1
).astype(int)

# %% [markdown]
# ### Multiple Installments
#
# This feature identifies orders that were paid using more than one installment, which may reflect different purchasing behaviors.

# %%
df["multiple_installments"] = (
    df["payment_installments"] > 1
).astype(int)

# %% [markdown]
# ### Large Product
#
# This feature identifies products with a volume above the dataset median, allowing products to be grouped into large and non-large categories.

# %%
df["large_product"] = (
    df["product_volume"]
    > df["product_volume"].median()
).astype(int)

# %% [markdown]
# ### Same-State Shipping
#
# This feature indicates whether the customer and the seller are located in the same state. Shorter shipping distances may lead to faster deliveries and higher customer satisfaction.

# %%
df["same_state"] = (
    df["customer_state"].astype(str)
    == df["seller_state"].astype(str)
).astype(int)

# %%
df["same_state"].value_counts()
# Out:
# same_state
# 0    75741
# 1    42405
# Name: count, dtype: int64

# %% [markdown]
# ### Night Purchase
#
# This feature identifies orders placed during late-night hours. Purchasing behavior may vary depending on the time of day.

# %%
df["night_purchase"] = (
    (
        df["purchase_hour"] >= 22
    )
    |
    (
        df["purchase_hour"] <= 6
    )
).astype(int)

# %% [markdown]
# ### Perfect Rating

# %%
df["perfect_review"] = (
    df["review_score"] == 5
).astype(int)

# %% [markdown]
# ### Early Delivery

# %%
df["early_delivery"] = (
    df["delivery_delay_days"] < 0
).astype(int)

# %% [markdown]
# ### Product Size Category

# %%
df["product_size_category"] = pd.qcut(
    df["product_volume"],
    q=4,
    labels=["Small", "Medium", "Large", "Very Large"]
)

# %% [markdown]
# ### Nmuber Of Products Per Order

# %%
items_per_order = (
    df.groupby("order_id")["order_item_id"]
    .max()
)

df = df.merge(
    items_per_order.rename("items_per_order"),
    on="order_id",
    how="left"
)
# Out:
# /tmp/ipykernel_1844/1936561257.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby("order_id")["order_item_id"]

# %%
df["items_per_order"].value_counts()
# Out:
# items_per_order
# 1.0     93478
# 2.0     15682
# 3.0      4137
# 4.0      2060
# 6.0      1188
# 5.0      1035
# 7.0       168
# 10.0       80
# 8.0        64
# 12.0       60
# 11.0       55
# 15.0       30
# 14.0       28
# 9.0        27
# 21.0       21
# 20.0       20
# 13.0       13
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (118146, 67)

# %%
df
# Out:
#                                 order_id                       customer_id  \
# 0       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3       53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 4       47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# ...                                  ...                               ...
# 118141  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 118142  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 118143  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 118144  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 118145  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#        order_status order_purchase_timestamp   order_approved_at  \
# ...

# %% [markdown]
# ## EDA

# %% [markdown]
# ## 1. Target Distribution — Rating
#
#  we analyze how customer ratings are distributed from **1 to 5**.
#
# We will check:
# - Number of observations for each rating
# - Percentage of each rating
# - Whether the target is concentrated around certain ratings
# - Mean, median and skewness

# %%
# Make sure Rating is numeric and valid

df = df.rename(columns={"review_score": "rating"})

df["rating"] = pd.to_numeric(df["rating"], errors="coerce")

rating_missing = df["rating"].isna().sum()
print("Missing rating values:", rating_missing)

# Model 3: drop rows where rating is missing
df = df.dropna(subset=["rating"]).copy()
df = df[df["rating"].between(1, 5)].copy()

rating_counts = df["rating"].value_counts().sort_index()
rating_percent = (
    df["rating"].value_counts(normalize=True).sort_index().mul(100).round(2)
)

print("\nRating counts:")
display(rating_counts.rename("count").to_frame())

print("\nRating percentages:")
display(rating_percent.rename("percentage").to_frame())

print(f"\nMean rating: {df['rating'].mean():.2f}")
print(f"Median rating: {df['rating'].median():.2f}")
print(f"Rating skewness: {df['rating'].skew():.3f}")
# Out:
# Missing rating values: 0
#
# Rating counts:
#         count
# rating
# 1.0     15428
# 2.0      4162
# 3.0      9894
# 4.0     22319
# 5.0     66343
# Rating percentages:
#         percentage
# rating
# 1.0          13.06
# 2.0           3.52
# 3.0           8.37
# 4.0          18.89
# 5.0          56.15
# Mean rating: 4.02
# Median rating: 5.00
# Rating skewness: -1.246

# %%
# Rating Distribution
plt.figure(figsize=(8, 5))
sns.countplot(
    data=df,
    x="rating",
    order=sorted(df["rating"].unique())
)
plt.title("Customer Rating Distribution")
plt.xlabel("Rating")
plt.ylabel("Number of Orders")
plt.tight_layout()
plt.savefig("visuals/01_rating_distribution.png", dpi=150, bbox_inches="tight")
plt.show()

# %% [markdown]
# ## 2. Feature Distribution
#
# Analyze the main Model 3 numerical variables, where available:
#
# - Age
# - Price
# - Quantity
# - Discount
# - Stock
# - Delivery Delay
# - Payment Value
# - Other engineered numerical features

# %%
# Select important numerical features that actually exist in the dataset
feature_candidates = [
    "age",
    "customer_age",
    "price",
    "quantity",
    "discount",
    "discount_percent",
    "stock",
    "stock_before_sale",
    "delivery_delay",
    "payment_value",
    "freight_value",
    "price_gap"
]

available_numeric = [
    c for c in feature_candidates
    if c in df.columns and pd.api.types.is_numeric_dtype(df[c])
]

print("Available numerical features:")
print(available_numeric)

for col in available_numeric:
    plt.figure(figsize=(8, 5))
    sns.histplot(df[col].dropna(), kde=True)
    plt.title(f"Distribution of {col}")
    plt.xlabel(col)
    plt.ylabel("Count")
    plt.tight_layout()
    plt.show()
# Out:
# Available numerical features:
# ['price', 'payment_value', 'freight_value']

# %%
# EDA Insight — Feature Distribution (computed, not generic)
skew_summary = df[available_numeric].skew().sort_values(key=abs, ascending=False)
top_skewed = skew_summary.head(3)

print("### Insight")
print("- **What happened?** The most skewed numerical features are: " +
      ", ".join([f"{name} (skew={val:.2f})" for name, val in top_skewed.items()]) + ".")
print("- **ML meaning:** Highly skewed features can pull Linear Regression coefficients and "
      "KNN distances toward extreme values; Decision Tree / Random Forest are far less sensitive.")
print("- **Business meaning:** A small share of orders sit far outside the typical range "
      "(e.g. very high shipping-cost ratio or very long delay) — these are the orders most "
      "likely to produce large prediction errors.")
print("- **Action / recommendation:** Keep StandardScaler in the pipeline (already used), and "
      "check the later error-by-category analysis to confirm these outliers do not dominate error.")
print("- **Limitation:** Skewness alone does not tell us whether outliers are genuine or "
      "data-entry mistakes; a dedicated outlier audit would be needed to confirm.")
print()
display(skew_summary.to_frame("skewness"))
# Out:
# ### Insight
# - **What happened?** The most skewed numerical features are: payment_value (skew=14.13), price (skew=7.68), freight_value (skew=5.57).
# - **ML meaning:** Highly skewed features can pull Linear Regression coefficients and KNN distances toward extreme values; Decision Tree / Random Forest are far less sensitive.
# - **Business meaning:** A small share of orders sit far outside the typical range (e.g. very high shipping-cost ratio or very long delay) — these are the orders most likely to produce large prediction errors.
# - **Action / recommendation:** Keep StandardScaler in the pipeline (already used), and check the later error-by-category analysis to confirm these outliers do not dominate error.
# - **Limitation:** Skewness alone does not tell us whether outliers are genuine or data-entry mistakes; a dedicated outlier audit would be needed to confirm.
#                 skewness
# payment_value  14.128141
# price           7.679035
# freight_value   5.572993

# %% [markdown]
# ### EDA Insight — Feature Distribution
#
# *(Computed, data-driven insight — see the printed output right below the histograms.)*

# %% [markdown]
# ## 3. Feature vs Target — Rating
#
# we calculate **Mean Rating** for each group.

# %%
def mean_rating_by_group(column, min_count=30):
    if column not in df.columns:
        return None

    result = (
        df.groupby(column, observed=True)["rating"]
          .agg(["mean", "count"])
          .query("count >= @min_count")
          .sort_values("mean", ascending=False)
    )
    return result.rename(columns={"mean": "mean_rating"})

# Category
category_col = next(
    (c for c in ["category", "product_category_name_english"]
     if c in df.columns),
    None
)

if category_col:
    print(f"Mean Rating by {category_col}:")
    display(mean_rating_by_group(category_col).head(15))

# Sales channel
channel_col = next(
    (c for c in ["sales_channel", "channel", "Sales_Channel"]
     if c in df.columns),
    None
)

if channel_col:
    print(f"Mean Rating by {channel_col}:")
    display(mean_rating_by_group(channel_col))

# Age groups
age_col = next(
    (c for c in ["age", "customer_age"]
     if c in df.columns and pd.api.types.is_numeric_dtype(df[c])),
    None
)

if age_col:
    temp = df[[age_col, "rating"]].dropna().copy()
    temp["age_group"] = pd.cut(
        temp[age_col],
        bins=[0, 18, 25, 35, 45, 55, 65, 120],
        labels=["<=18", "19-25", "26-35", "36-45", "46-55", "56-65", "65+"],
        include_lowest=True
    )

    age_rating = (
        temp.groupby("age_group", observed=True)["rating"]
            .agg(["mean", "count"])
            .rename(columns={"mean": "mean_rating"})
    )

    print("Mean Rating by Age Group:")
    display(age_rating)

# Discount groups
discount_col = next(
    (c for c in ["discount_percent", "discount", "discount_percentage"]
     if c in df.columns and pd.api.types.is_numeric_dtype(df[c])),
    None
)

if discount_col:
    temp = df[[discount_col, "rating"]].dropna().copy()
    temp["discount_group"] = pd.qcut(
        temp[discount_col],
        q=5,
        duplicates="drop"
    )

    discount_rating = (
        temp.groupby("discount_group", observed=True)["rating"]
            .agg(["mean", "count"])
            .rename(columns={"mean": "mean_rating"})
    )

    print("Mean Rating by Discount Group:")
    display(discount_rating)

# Stock groups
stock_col = next(
    (c for c in ["stock_before_sale", "stock", "Stock"]
     if c in df.columns and pd.api.types.is_numeric_dtype(df[c])),
    None
)

if stock_col:
    temp = df[[stock_col, "rating"]].dropna().copy()
    temp["stock_group"] = pd.qcut(
        temp[stock_col],
        q=4,
        duplicates="drop"
    )

    stock_rating = (
        temp.groupby("stock_group", observed=True)["rating"]
            .agg(["mean", "count"])
            .rename(columns={"mean": "mean_rating"})
    )

    print("Mean Rating by Stock Group:")
    display(stock_rating)
# Out:
# Mean Rating by product_category_name_english:
#                                        mean_rating  count
# product_category_name_english
# books_general_interest                    4.438503    561
# books_imported                            4.419355     62
# flowers                                   4.419355     31
# costruction_tools_tools                   4.415842    101
# books_technical                           4.375465    269
# food_drink                                4.324138    290
# small_appliances_home_oven_and_coffee     4.320513     78
# luggage_accessories                       4.295945   1159
# fashion_sport                             4.258065     31
# food                                      4.228963    511
# fashion_shoes                             4.223443    273
# cine_photo                                4.216216     74
# home_appliances_2                         4.212687    268
# music                                     4.200000     40
# ...

# %% [markdown]
# # Visual: Top 10 Product Categories by Mean Rating

# %%
if category_col:

    # Calculate mean rating + number of ratings per category
    category_plot = (
        df.groupby(category_col, observed=True)["rating"]
          .agg(["mean", "count"])
          .rename(columns={"mean": "mean_rating", "count": "rating_count"})
    )

    # Keep only categories with enough ratings
    category_plot = (
        category_plot[category_plot["rating_count"] >= 100]
        .sort_values("mean_rating", ascending=False)
        .head(10)
        .sort_values("mean_rating", ascending=True)
    )

    # Plot
    plt.figure(figsize=(10, 6))

    bars = plt.barh(
        category_plot.index,
        category_plot["mean_rating"]
    )

    plt.title("Top 10 Product Categories by Mean Rating")
    plt.xlabel("Mean Rating")
    plt.ylabel("Product Category")

    # Rating range
    plt.xlim(1, 5)

    # Add rating value at the end of each bar
    for bar, value in zip(bars, category_plot["mean_rating"]):
        plt.text(
            value + 0.03,
            bar.get_y() + bar.get_height() / 2,
            f"{value:.2f}",
            va="center"
        )

    plt.tight_layout()
    plt.show()

# %% [markdown]
# # Visual: Mean Rating by Payment Type

# %%
payment_col = "payment_type"

payment_plot = (
    df.groupby(payment_col, observed=True)["rating"]
      .mean()
      .sort_values(ascending=False)
)

plt.figure(figsize=(8, 5))

sns.barplot(
    x=payment_plot.index,
    y=payment_plot.values
)

plt.title("Mean Rating by Payment Type")
plt.xlabel("Payment Type")
plt.ylabel("Mean Rating")
plt.ylim(1, 5)
plt.xticks(rotation=25)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Visual: Mean Rating by Freight Value Group

# %%
temp = df[["freight_value", "rating"]].dropna().copy()

temp["freight_group"] = pd.qcut(
    temp["freight_value"],
    q=5,
    duplicates="drop"
)

freight_rating = (
    temp.groupby("freight_group", observed=True)["rating"]
        .mean()
)

plt.figure(figsize=(10, 5))

sns.barplot(
    x=freight_rating.index.astype(str),
    y=freight_rating.values
)

plt.title("Mean Rating by Freight Value Group")
plt.xlabel("Freight Value Group")
plt.ylabel("Mean Rating")
plt.ylim(1, 5)
plt.xticks(rotation=25)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Visual: Mean Rating by Product Size Category

# %%
size_col = "product_size_category"

size_rating = (
    df.groupby(size_col, observed=True)["rating"]
      .mean()
      .sort_values(ascending=False)
)

plt.figure(figsize=(9, 5))

sns.barplot(
    x=size_rating.index,
    y=size_rating.values
)

plt.title("Mean Rating by Product Size Category")
plt.xlabel("Product Size Category")
plt.ylabel("Mean Rating")
plt.ylim(1, 5)
plt.xticks(rotation=25)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 4. Correlation Analysis
#
# We analyze the correlation between `rating` and numerical variables.
#
# The purpose is to identify variables with stronger linear relationships with customer rating.

# %%
corr_candidates = [
    c for c in [
        "rating",
        "age",
        "customer_age",
        "price",
        "quantity",
        "discount",
        "discount_percent",
        "stock",
        "stock_before_sale",
        "delivery_delay",
        "payment_value",
        "freight_value",
        "price_gap"
    ]
    if c in df.columns and pd.api.types.is_numeric_dtype(df[c])
]

corr_matrix = df[corr_candidates].corr()

plt.figure(figsize=(11, 8))
sns.heatmap(
    corr_matrix,
    annot=True,
    fmt=".2f",
    cmap="coolwarm",
    center=0
)
plt.title("Correlation Matrix — Rating and Numerical Features")
plt.tight_layout()
plt.savefig("visuals/02_correlation_heatmap.png", dpi=150, bbox_inches="tight")
plt.show()

print("Correlation with Rating:")
display(
    corr_matrix["rating"]
    .drop("rating")
    .sort_values(key=abs, ascending=False)
    .to_frame("correlation_with_rating")
)
# Out:
# Correlation with Rating:
#                correlation_with_rating
# payment_value                -0.082325
# freight_value                -0.033888
# price                        -0.001631

# %%
# EDA Insight — Correlation (computed, not generic)
corr_with_rating = corr_matrix["rating"].drop("rating").sort_values(key=abs, ascending=False)
top_pos = corr_with_rating[corr_with_rating > 0].head(1)
top_neg = corr_with_rating[corr_with_rating < 0].head(1)

print("### Insight")
if len(top_pos) and len(top_neg):
    print(f"- **What happened?** Strongest positive correlation with rating: "
          f"{top_pos.index[0]} ({top_pos.iloc[0]:.3f}). Strongest negative correlation: "
          f"{top_neg.index[0]} ({top_neg.iloc[0]:.3f}).")
print("- **ML meaning:** These linear correlations set expectations for the Linear Regression "
      "baseline; tree-based models can still capture non-linear relationships correlation misses.")
print("- **Business meaning:** Features that move rating clearly in one direction point directly "
      "at operational levers the business can act on.")
print("- **Action / recommendation:** Prioritise fixes for the feature with the strongest negative "
      "correlation first, since it is the clearest linear driver of low ratings.")
print("- **Limitation:** Correlation only captures linear relationships and is not proof of "
      "causation — a feature can be a proxy for something else (e.g. product category).")
print()
display(corr_with_rating.to_frame("correlation_with_rating"))
# Out:
# ### Insight
# - **ML meaning:** These linear correlations set expectations for the Linear Regression baseline; tree-based models can still capture non-linear relationships correlation misses.
# - **Business meaning:** Features that move rating clearly in one direction point directly at operational levers the business can act on.
# - **Action / recommendation:** Prioritise fixes for the feature with the strongest negative correlation first, since it is the clearest linear driver of low ratings.
# - **Limitation:** Correlation only captures linear relationships and is not proof of causation — a feature can be a proxy for something else (e.g. product category).
#                correlation_with_rating
# payment_value                -0.082325
# freight_value                -0.033888
# price                        -0.001631

# %% [markdown]
# ### EDA Insight — Correlation
#
# *(Computed, data-driven insight — see the printed output right below the heatmap.)*

# %% [markdown]
# ## 5. Time Analysis
#
# If an order date/time column exists, we analyze:
# - Average rating over time
# - Monthly rating patterns
# - Weekday rating patterns

# %%
date_col = next(
    (c for c in [
        "order_date",
        "order_purchase_timestamp",
        "Order_Date"
    ] if c in df.columns),
    None
)

if date_col:
    time_df = df[[date_col, "rating"]].copy()
    time_df[date_col] = pd.to_datetime(time_df[date_col], errors="coerce")
    time_df = time_df.dropna(subset=[date_col])

    time_df["month"] = time_df[date_col].dt.to_period("M").astype(str)
    time_df["weekday"] = time_df[date_col].dt.day_name()

    monthly_rating = time_df.groupby("month")["rating"].mean()

    plt.figure(figsize=(12, 5))
    sns.lineplot(
        x=monthly_rating.index,
        y=monthly_rating.values,
        marker="o"
    )
    plt.title("Average Rating Over Time")
    plt.xlabel("Month")
    plt.ylabel("Mean Rating")
    plt.ylim(1, 5)
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

    weekday_order = [
        "Monday", "Tuesday", "Wednesday",
        "Thursday", "Friday", "Saturday", "Sunday"
    ]

    weekday_rating = (
        time_df.groupby("weekday")["rating"]
        .mean()
        .reindex(weekday_order)
    )

    plt.figure(figsize=(10, 5))
    sns.barplot(
        x=weekday_rating.index,
        y=weekday_rating.values
    )
    plt.title("Average Rating by Purchase Weekday")
    plt.xlabel("Weekday")
    plt.ylabel("Mean Rating")
    plt.ylim(1, 5)
    plt.xticks(rotation=25)
    plt.tight_layout()
    plt.show()
else:
    print("No suitable date column was found; time analysis was skipped.")

# %%
# EDA Insight — Time Analysis (computed, not generic)
if date_col:
    best_month, worst_month = monthly_rating.idxmax(), monthly_rating.idxmin()
    best_weekday, worst_weekday = weekday_rating.idxmax(), weekday_rating.idxmin()

    print("### Insight")
    print(f"- **What happened?** Highest average rating: {best_month} "
          f"({monthly_rating.max():.2f}); lowest: {worst_month} ({monthly_rating.min():.2f}). "
          f"By weekday: {best_weekday} averaged {weekday_rating.max():.2f} vs "
          f"{worst_weekday} at {weekday_rating.min():.2f}.")
    print("- **ML meaning:** purchase_month/weekday/quarter are kept as features so the model "
          "can capture any seasonal pattern, even though the swing looks modest.")
    print("- **Business meaning:** Time-based swings this small are unlikely to reflect a real "
          "seasonal effect on satisfaction — operational factors (delivery, order status) matter more.")
    print("- **Action / recommendation:** Do not prioritise timing-based interventions; focus "
          "resources on delivery performance and order fulfilment instead.")
    print("- **Limitation:** This is an aggregate view — it does not control for other factors "
          "(e.g. a specific month having more delays) that could be the real driver.")
else:
    print("No suitable date column was found; time analysis was skipped.")
# Out:
# ### Insight
# - **What happened?** Highest average rating: 2016-12 (5.00); lowest: 2016-09 (1.00). By weekday: Wednesday averaged 4.05 vs Friday at 3.96.
# - **ML meaning:** purchase_month/weekday/quarter are kept as features so the model can capture any seasonal pattern, even though the swing looks modest.
# - **Business meaning:** Time-based swings this small are unlikely to reflect a real seasonal effect on satisfaction — operational factors (delivery, order status) matter more.
# - **Action / recommendation:** Do not prioritise timing-based interventions; focus resources on delivery performance and order fulfilment instead.
# - **Limitation:** This is an aggregate view — it does not control for other factors (e.g. a specific month having more delays) that could be the real driver.

# %% [markdown]
# ### EDA Insight — Time Analysis
#
# *(Computed, data-driven insight — see the printed output right below the time charts.)*

# %% [markdown]
# # Linear Regression

# %%
# Model 3 feature preparation
# NOTE: 'has_review_comment' was intentionally EXCLUDED — it is generated at the
# same moment the customer submits the review/rating, so it would not be available
# at real prediction time (before the review exists). Keeping it would be a subtle
# form of target leakage. See Limitations (section 16) for details.
model3_features = [
    # Delivery — most important predictors
    "delivery_days",
    "expected_delivery_days",
    "delivery_delay_days",
    "is_delayed",
    "delivery_speed_ratio",
    "early_delivery",

    # Pricing
    "price",
    "shipping_price_ratio",
    "average_installment_value",
    "total_cost",

    # Category / payment / status
    "product_category_name_english",
    "payment_type",
    "order_status",

    # Time
    "purchase_month",
    "purchase_weekday",
    "purchase_hour",
    "is_weekend",
    "purchase_quarter",
    "approval_time_hours",
    "shipping_preparation_hours",

    # Product
    "product_volume",
    "product_density",
    "product_size_category",
    "large_product",

    # Order behavior
    "items_per_order",
    "same_state",
    "night_purchase",
    "has_multiple_photos",
    "multiple_installments",
]

model3_features = [
    c for c in model3_features
    if c in df.columns and c != "rating"
]

X = df[model3_features].copy()
y = df["rating"].astype(float)

X = X.replace([np.inf, -np.inf], np.nan)

print("Model 3 features:")
print(model3_features)
print("X shape:", X.shape)
print("y shape:", y.shape)
# Out:
# Model 3 features:
# ['delivery_days', 'expected_delivery_days', 'delivery_delay_days', 'is_delayed', 'delivery_speed_ratio', 'early_delivery', 'price', 'shipping_price_ratio', 'average_installment_value', 'total_cost', 'product_category_name_english', 'payment_type', 'order_status', 'purchase_month', 'purchase_weekday', 'purchase_hour', 'is_weekend', 'purchase_quarter', 'approval_time_hours', 'shipping_preparation_hours', 'product_volume', 'product_density', 'product_size_category', 'large_product', 'items_per_order', 'same_state', 'night_purchase', 'has_multiple_photos', 'multiple_installments']
# X shape: (118146, 29)
# y shape: (118146,)

# %%
# Train/Test Split
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=RANDOM_STATE
)

numeric_features = X_train.select_dtypes(include=np.number).columns.tolist()
categorical_features = X_train.select_dtypes(
    include=["object", "category", "bool"]
).columns.tolist()

numeric_transformer = Pipeline(steps=[
    ("imputer", SimpleImputer(strategy="median")),
    ("scaler", StandardScaler())
])

categorical_transformer = Pipeline(steps=[
    ("imputer", SimpleImputer(strategy="most_frequent")),
    ("onehot", OneHotEncoder(handle_unknown="ignore"))
])

preprocessor = ColumnTransformer(
    transformers=[
        ("num", numeric_transformer, numeric_features),
        ("cat", categorical_transformer, categorical_features)
    ]
)

print("Numeric features:", numeric_features)
print("Categorical features:", categorical_features)
# Out:
# Numeric features: ['delivery_days', 'expected_delivery_days', 'delivery_delay_days', 'is_delayed', 'delivery_speed_ratio', 'early_delivery', 'price', 'shipping_price_ratio', 'average_installment_value', 'total_cost', 'purchase_month', 'purchase_weekday', 'purchase_hour', 'is_weekend', 'purchase_quarter', 'approval_time_hours', 'shipping_preparation_hours', 'product_volume', 'product_density', 'large_product', 'items_per_order', 'same_state', 'night_purchase', 'has_multiple_photos', 'multiple_installments']
# Categorical features: ['product_category_name_english', 'payment_type', 'order_status', 'product_size_category']

# %%
for col in numeric_features:
    n_inf = np.isinf(X_train[col]).sum()
    if n_inf > 0:
        print(col, "->", n_inf, "infinite values")

# %%
X = df[model3_features].copy()
y = df["rating"].astype(float)

# Replace infinite values with NaN so the imputer can handle them
X = X.replace([np.inf, -np.inf], np.nan)

print("Model 3 features:")
print(model3_features)
print("X shape:", X.shape)
print("y shape:", y.shape)
# Out:
# Model 3 features:
# ['delivery_days', 'expected_delivery_days', 'delivery_delay_days', 'is_delayed', 'delivery_speed_ratio', 'early_delivery', 'price', 'shipping_price_ratio', 'average_installment_value', 'total_cost', 'product_category_name_english', 'payment_type', 'order_status', 'purchase_month', 'purchase_weekday', 'purchase_hour', 'is_weekend', 'purchase_quarter', 'approval_time_hours', 'shipping_preparation_hours', 'product_volume', 'product_density', 'product_size_category', 'large_product', 'items_per_order', 'same_state', 'night_purchase', 'has_multiple_photos', 'multiple_installments']
# X shape: (118146, 29)
# y shape: (118146,)

# %%
# Linear Regression

linear_model = Pipeline(steps=[
    ("preprocessor", preprocessor),
    ("regressor", LinearRegression())
])

linear_model.fit(X_train, y_train)
y_pred = linear_model.predict(X_test)

mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
r2 = r2_score(y_test, y_pred)

model_comparison = pd.DataFrame([{
    "Model": "Linear Regression",
    "MAE": mae,
    "RMSE": rmse,
    "R2": r2
}])

display(model_comparison.round(4))
# Out:
#                Model     MAE    RMSE      R2
# 0  Linear Regression  0.9624  1.2361  0.2211

# %% [markdown]
# # Decision Tree

# %%
tree_model = Pipeline(steps=[
    ("preprocessor", preprocessor),
    ("regressor", DecisionTreeRegressor(random_state=RANDOM_STATE))
])

tree_model.fit(X_train, y_train)
y_pred = tree_model.predict(X_test)

mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
r2 = r2_score(y_test, y_pred)

model_comparison = pd.concat([
    model_comparison,
    pd.DataFrame([{
        "Model": "Decision Tree",
        "MAE": mae,
        "RMSE": rmse,
        "R2": r2
    }])
], ignore_index=True)

display(model_comparison.round(4))
# Out:
#                Model     MAE    RMSE      R2
# 0  Linear Regression  0.9624  1.2361  0.2211
# 1      Decision Tree  0.8429  1.4558 -0.0804

# %% [markdown]
# # Random Forest

# %%
forest_model = Pipeline(steps=[
    ("preprocessor", preprocessor),
    ("regressor", RandomForestRegressor(
    n_estimators=50,
    max_depth=10,
    random_state=RANDOM_STATE,
    n_jobs=-1
))
])

forest_model.fit(X_train, y_train)
y_pred = forest_model.predict(X_test)

mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
r2 = r2_score(y_test, y_pred)

model_comparison = pd.concat([
    model_comparison,
    pd.DataFrame([{
        "Model": "Random Forest",
        "MAE": mae,
        "RMSE": rmse,
        "R2": r2
    }])
], ignore_index=True)

display(model_comparison.round(4))
# Out:
#                Model     MAE    RMSE      R2
# 0  Linear Regression  0.9624  1.2361  0.2211
# 1      Decision Tree  0.8429  1.4558 -0.0804
# 2      Random Forest  0.9088  1.1695  0.3027

# %% [markdown]
# # KNN Regressor

# %%
knn_model = Pipeline(steps=[
    ("preprocessor", preprocessor),
    ("regressor", KNeighborsRegressor())
])

knn_model.fit(X_train, y_train)
y_pred = knn_model.predict(X_test)

mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
r2 = r2_score(y_test, y_pred)

model_comparison = pd.concat([
    model_comparison,
    pd.DataFrame([{
        "Model": "KNN",
        "MAE": mae,
        "RMSE": rmse,
        "R2": r2
    }])
], ignore_index=True)

display(model_comparison.round(4))
# Out:
#                Model     MAE    RMSE      R2
# 0  Linear Regression  0.9624  1.2361  0.2211
# 1      Decision Tree  0.8429  1.4558 -0.0804
# 2      Random Forest  0.9088  1.1695  0.3027
# 3                KNN  0.8856  1.2326  0.2254

# %% [markdown]
# # Model Comparison

# %% [markdown]
# ### Insight
# - **What happened?** Compare the four regression algorithms (Linear Regression, Decision Tree, Random Forest, KNN) trained on the same train/test split using MAE, RMSE, and R².
# - **ML meaning:** Lower MAE/RMSE and higher R² indicate a model that predicts the customer rating more accurately and explains more of the variance in the target.
# - **Business meaning:** A more accurate rating-prediction model lets the business flag at-risk orders (likely to receive low ratings) before the customer actually reviews them.
# - **Action / recommendation:** Move forward with the best-performing algorithm and tune it further with GridSearchCV instead of tuning all four models.
# - **Limitation:** Results depend on this specific train/test split and the engineered features available; performance may shift with different feature sets or more data.

# %%
model_comparison_sorted = model_comparison.sort_values(
    by=["MAE", "RMSE"], ascending=[True, True]
).reset_index(drop=True)

display(model_comparison_sorted.round(4))
# Out:
#                Model     MAE    RMSE      R2
# 0      Decision Tree  0.8429  1.4558 -0.0804
# 1                KNN  0.8856  1.2326  0.2254
# 2      Random Forest  0.9088  1.1695  0.3027
# 3  Linear Regression  0.9624  1.2361  0.2211

# %% [markdown]
# # Winner Selection

# %%
# Winner = lowest MAE (primary criterion), with RMSE and R2 as supporting evidence
winner_row = model_comparison_sorted.iloc[0]
winner_name = winner_row["Model"]

print(f"Best model based on MAE/RMSE/R2: {winner_name}")
display(winner_row.to_frame().T.round(4))

models_dict = {
    "Linear Regression": linear_model,
    "Decision Tree": tree_model,
    "Random Forest": forest_model,
    "KNN": knn_model
}

winner_model = models_dict[winner_name]
# Out:
# Best model based on MAE/RMSE/R2: Decision Tree
#            Model       MAE      RMSE        R2
# 0  Decision Tree  0.842934  1.455776 -0.080379

# %% [markdown]
# # GridSearchCV — Tuning the Winner Only

# %%
# Define the parameter grid depending on which model won
# (Only the winner is tuned — not all four models)

param_grids = {
    "Decision Tree": {
        "regressor__max_depth": [5, 10, None],
        "regressor__min_samples_split": [2, 5],
        "regressor__min_samples_leaf": [1, 2]
    },
    "Random Forest": {
        "regressor__n_estimators": [100, 200],
        "regressor__max_depth": [5, 10, None],
        "regressor__min_samples_split": [2, 5]
    },
    "KNN": {
        "regressor__n_neighbors": [3, 5, 7, 9],
        "regressor__weights": ["uniform", "distance"]
    },
    "Linear Regression": {
        "regressor__fit_intercept": [True, False]
    }
}

param_grid = param_grids[winner_name]

grid = GridSearchCV(
    winner_model,
    param_grid,
    cv=5,
    scoring="neg_root_mean_squared_error",
    n_jobs=-1
)

grid.fit(X_train, y_train)

print(f"Best params for {winner_name}:", grid.best_params_)
print(f"Best CV RMSE: {-grid.best_score_:.4f}")

tuned_model = grid.best_estimator_
# Out:
# Best params for Decision Tree: {'regressor__max_depth': 10, 'regressor__min_samples_leaf': 2, 'regressor__min_samples_split': 5}
# Best CV RMSE: 1.2052

# %%
# Evaluate the tuned winner on the test set
y_pred_tuned = tuned_model.predict(X_test)

mae_tuned = mean_absolute_error(y_test, y_pred_tuned)
rmse_tuned = np.sqrt(mean_squared_error(y_test, y_pred_tuned))
r2_tuned = r2_score(y_test, y_pred_tuned)

model_comparison_final = pd.concat([
    model_comparison,
    pd.DataFrame([{
        "Model": f"{winner_name} (Tuned)",
        "MAE": mae_tuned,
        "RMSE": rmse_tuned,
        "R2": r2_tuned
    }])
], ignore_index=True)

model_comparison_final["Tuned"] = model_comparison_final["Model"].str.contains("Tuned")
model_comparison_final["Selected"] = model_comparison_final["Model"] == f"{winner_name} (Tuned)"

display(model_comparison_final.round(4))
# Out:
#                    Model     MAE    RMSE      R2  Tuned  Selected
# 0      Linear Regression  0.9624  1.2361  0.2211  False     False
# 1          Decision Tree  0.8429  1.4558 -0.0804  False     False
# 2          Random Forest  0.9088  1.1695  0.3027  False     False
# 3                    KNN  0.8856  1.2326  0.2254  False     False
# 4  Decision Tree (Tuned)  0.9182  1.2053  0.2594   True      True

# %%
print("Categorical features:", categorical_features)
print()
for col in categorical_features:
    print(col, "->", X_train[col].nunique(), "unique values")
# Out:
# Categorical features: ['product_category_name_english', 'payment_type', 'order_status', 'product_size_category']
#
# product_category_name_english -> 72 unique values
# payment_type -> 6 unique values
# order_status -> 7 unique values
# product_size_category -> 4 unique values

# %%
print([c for c in df.columns if "delay" in c.lower() or "delivery" in c.lower()])
print([c for c in df.columns if "discount" in c.lower() or "price" in c.lower()])
print([c for c in df.columns if "age" in c.lower() or "quantity" in c.lower() or "stock" in c.lower()])
print([c for c in df.columns if "channel" in c.lower() or "courier" in c.lower() or "status" in c.lower()])
# Out:
# ['order_estimated_delivery_date', 'delivery_days', 'expected_delivery_days', 'delivery_delay_days', 'is_delayed', 'delivery_speed_ratio', 'early_delivery']
# ['price', 'shipping_price_ratio']
# ['review_comment_message', 'average_installment_value']
# ['order_status']

# %% [markdown]
# #  Target Distribution Analysis
#
# Check whether the  target is skewed, and compare raw vs log-transformed distribution.

# %%
# Target Distribution: Raw vs Log-transformed

from scipy import stats

target = y  # review_score (1-5)

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# --- Raw distribution ---
ax1 = axes[0]
counts = target.value_counts().sort_index()
bars = ax1.bar(counts.index, counts.values,
               color=["#e74c3c","#e67e22","#f1c40f","#2ecc71","#27ae60"],
               edgecolor="white", linewidth=0.8)
for bar, val in zip(bars, counts.values):
    ax1.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 200,
             f"{val:,}", ha="center", va="bottom", fontsize=9, fontweight="bold")
skew_raw = float(target.skew())
ax1.set_title(f"Raw Rating Distribution\
(skewness = {skew_raw:.3f})", fontsize=13)
ax1.set_xlabel("Review Score", fontsize=11)
ax1.set_ylabel("Count", fontsize=11)
ax1.set_xticks([1,2,3,4,5])

# --- Log-transformed distribution ---
ax2 = axes[1]
target_log = np.log1p(target)
ax2.hist(target_log, bins=40, color="#3498db", edgecolor="white", linewidth=0.6)
skew_log = float(target_log.skew())
ax2.set_title(f"Log-transformed (log1p) Rating\
(skewness = {skew_log:.3f})", fontsize=13)
ax2.set_xlabel("log1p(Review Score)", fontsize=11)
ax2.set_ylabel("Count", fontsize=11)

plt.suptitle("Target Distribution: Raw vs Log-Transformed", fontsize=15, fontweight="bold", y=1.02)
plt.tight_layout()
plt.savefig("visuals/03_target_distribution.png", dpi=150, bbox_inches="tight")
plt.show()

print(f"Raw  skewness : {skew_raw:.4f}")
print(f"Log1p skewness: {skew_log:.4f}")
print(f"Raw rating stats:")
print(target.describe().round(3))

# Interpretation
if abs(skew_raw) > 0.5:
    direction = "negatively" if skew_raw < 0 else "positively"
    print(f"\
Conclusion: The raw target is {direction} skewed (|skew|={abs(skew_raw):.2f} > 0.5).")
    print("Rating 5 dominates — the distribution is left-skewed.")
else:
    print("Conclusion: Target is approximately symmetric.")
# Out:
# Raw  skewness : -1.2458
# Log1p skewness: -1.5491
# Raw rating stats:
# count    118146.000
# mean          4.016
# std           1.400
# min           1.000
# 25%           4.000
# 50%           5.000
# 75%           5.000
# max           5.000
# Name: rating, dtype: float64
# Conclusion: The raw target is negatively skewed (|skew|=1.25 > 0.5).
# Rating 5 dominates — the distribution is left-skewed.

# %% [markdown]
# ### Insight — Target Distribution
#
# The raw  is **strongly left-skewed**: rating 5 accounts for the largest share of observations.
# “The target variable is highly concentrated toward 5 stars, with approximately 56% of orders receiving the maximum rating. The negative skewness of -1.246 indicates a long tail of lower ratings. Applying log1p increased the skewness to -1.549, so the transformation did not improve the target distribution. This imbalance means the model may be better at predicting high ratings than identifying low-rating orders, which should be considered during error analysis.”

# %% [markdown]
# #  Model Evaluation — Tuned Model
#
# MAE, RMSE, and R² for the tuned winner model on the held-out test set.

# %%
# Re-compute predictions with the tuned model (already fitted above)
y_pred_final = tuned_model.predict(X_test)

mae_final  = mean_absolute_error(y_test, y_pred_final)
rmse_final = np.sqrt(mean_squared_error(y_test, y_pred_final))
r2_final   = r2_score(y_test, y_pred_final)

print("="*45)
print(f"  Tuned {winner_name} — Test-Set Evaluation")
print("="*45)
print(f"  MAE  : {mae_final:.4f}  (avg absolute error in rating points)")
print(f"  RMSE : {rmse_final:.4f}  (penalises large errors more)")
print(f"  R²   : {r2_final:.4f}  (fraction of variance explained)")
print("="*45)

import pandas as pd
eval_df = pd.DataFrame([{
    "Metric": "MAE",  "Value": round(mae_final, 4),
    "Interpretation": "Avg rating prediction error (lower = better)"
}, {
    "Metric": "RMSE", "Value": round(rmse_final, 4),
    "Interpretation": "Penalises large prediction errors more (lower = better)"
}, {
    "Metric": "R²",   "Value": round(r2_final, 4),
    "Interpretation": "% variance explained (higher = better)"
}])
display(eval_df)
# Out:
# ...
#   Tuned Decision Tree — Test-Set Evaluation
# ...
#   MAE  : 0.9182  (avg absolute error in rating points)
#   RMSE : 1.2053  (penalises large errors more)
#   R²   : 0.2594  (fraction of variance explained)
# ...
#   Metric   Value                                     Interpretation
# 0    MAE  0.9182       Avg rating prediction error (lower = better)
# 1   RMSE  1.2053  Penalises large prediction errors more (lower ...
# 2     R²  0.2594             % variance explained (higher = better)

# %% [markdown]
# #  Feature Importance — Tuned Winner Model
#
# Which features drive the tuned model's predictions the most.

# %%
# Feature Importance / Coefficients for the tuned winner model
reg = tuned_model.named_steps["regressor"]
feat_names = tuned_model.named_steps["preprocessor"].get_feature_names_out()

top3 = None

if hasattr(reg, "feature_importances_"):
    importances = pd.Series(reg.feature_importances_, index=feat_names).sort_values(ascending=False)
    top_importances = importances.head(15)
    top3 = importances.head(3)

    plt.figure(figsize=(9, 7))
    sns.barplot(x=top_importances.values, y=top_importances.index, color="#2c3e50")
    plt.title(f"Top 15 Feature Importances — {winner_name} (Tuned)")
    plt.xlabel("Importance")
    plt.ylabel("Feature")
    plt.tight_layout()
    plt.savefig("visuals/06_feature_importance.png", dpi=150, bbox_inches="tight")
    plt.show()
    display(top_importances.to_frame("importance"))

elif hasattr(reg, "coef_"):
    coefs = pd.Series(reg.coef_, index=feat_names).sort_values(key=abs, ascending=False)
    top_coefs = coefs.head(15)
    top3 = coefs.head(3)

    plt.figure(figsize=(9, 7))
    sns.barplot(x=top_coefs.values, y=top_coefs.index, color="#2c3e50")
    plt.title(f"Top 15 Coefficients (by magnitude) — {winner_name} (Tuned)")
    plt.xlabel("Coefficient")
    plt.ylabel("Feature")
    plt.tight_layout()
    plt.savefig("visuals/06_feature_importance.png", dpi=150, bbox_inches="tight")
    plt.show()
    display(top_coefs.to_frame("coefficient"))

else:
    print(f"{winner_name} does not expose feature_importances_ or coef_ (e.g. KNN) — skipping plot.")

print()
print("### Insight")
if top3 is not None:
    print(f"- **What happened?** The top 3 features for the tuned {winner_name} are: " +
          ", ".join([f"{n} ({v:.3f})" for n, v in top3.items()]) + ".")
    print("- **ML meaning:** The model relies most heavily on these features to produce its predictions.")
    print("- **Business meaning:** These are the levers the business should track most closely, since "
          "the model learned they carry the most predictive signal for satisfaction.")
    print("- **Action / recommendation:** Cross-check these against the business insights below and "
          "prioritise fixes for features the business can actually control (e.g. delivery delay) "
          "over ones it cannot (e.g. purchase timing).")
    print("- **Limitation:** Feature importance reflects learned patterns, not proven causal effects; "
          "correlated features can split importance between them.")
else:
    print("- Feature importance is not available for this algorithm type (e.g. KNN has no coefficients "
          "or importances) — refer to the correlation and business-insight sections instead.")
# Out:
#                                  importance
# num__early_delivery                0.469998
# num__items_per_order               0.131570
# cat__order_status_delivered        0.084491
# num__delivery_delay_days           0.074930
# num__delivery_days                 0.031180
# num__expected_delivery_days        0.022825
# num__approval_time_hours           0.022421
# num__shipping_preparation_hours    0.020026
# num__product_density               0.019456
# num__delivery_speed_ratio          0.018554
# num__product_volume                0.015589
# num__average_installment_value     0.014260
# num__purchase_month                0.008790
# num__total_cost                    0.008646
# num__shipping_price_ratio          0.008144
# ### Insight
# - **What happened?** The top 3 features for the tuned Decision Tree are: num__early_delivery (0.470), num__items_per_order (0.132), cat__order_status_delivered (0.084).
# ...

# %% [markdown]
# #  Visualisations
#
# ## a. Predicted vs Actual scatter plot

# %%
fig, ax = plt.subplots(figsize=(8, 7))

# Scatter with transparency to handle overplotting
ax.scatter(y_test, y_pred_final, alpha=0.15, s=15,
           color="#2980b9", label="Predictions")

# Perfect-prediction line
lims = [1, 5]
ax.plot(lims, lims, "r--", linewidth=2, label="Perfect prediction")

# Regression line through predictions
from numpy.polynomial.polynomial import polyfit
b, m = polyfit(y_test, y_pred_final, 1)
ax.plot(lims, [b + m*x for x in lims], color="orange",
        linewidth=1.8, linestyle="-", label="Trend line")

ax.set_xlim(0.5, 5.5)
ax.set_ylim(0.5, 5.5)
ax.set_xlabel("Actual Rating", fontsize=12)
ax.set_ylabel("Predicted Rating", fontsize=12)
ax.set_title(f"Predicted vs Actual — {winner_name} (Tuned)\
"
             f"MAE={mae_final:.3f}  RMSE={rmse_final:.3f}  R²={r2_final:.3f}",
             fontsize=12)
ax.legend(fontsize=10)
ax.set_xticks([1,2,3,4,5])
ax.set_yticks([1,2,3,4,5])
plt.tight_layout()
plt.savefig("visuals/04_predicted_vs_actual.png", dpi=150, bbox_inches="tight")
plt.show()

# %% [markdown]
# ## b. Residual Plot

# %%
residuals = y_test - y_pred_final

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Residuals vs Predicted
ax1 = axes[0]
ax1.scatter(y_pred_final, residuals, alpha=0.15, s=12, color="#8e44ad")
ax1.axhline(0, color="red", linewidth=1.8, linestyle="--")
ax1.set_xlabel("Predicted Rating", fontsize=12)
ax1.set_ylabel("Residual (Actual − Predicted)", fontsize=12)
ax1.set_title("Residuals vs Predicted Values", fontsize=13)

# Residual histogram
ax2 = axes[1]
ax2.hist(residuals, bins=50, color="#16a085", edgecolor="white", linewidth=0.5)
ax2.axvline(0, color="red", linewidth=1.8, linestyle="--")
ax2.set_xlabel("Residual", fontsize=12)
ax2.set_ylabel("Frequency", fontsize=12)
ax2.set_title(f"Residual Distribution\
"
              f"Mean={float(residuals.mean()):.3f}  Std={float(residuals.std()):.3f}",
              fontsize=13)

plt.suptitle("Residual Analysis", fontsize=15, fontweight="bold")
plt.tight_layout()
plt.savefig("visuals/05_residuals.png", dpi=150, bbox_inches="tight")
plt.show()

print(f"Residual mean : {float(residuals.mean()):.4f}  (close to 0 = unbiased)")
print(f"Residual std  : {float(residuals.std()):.4f}")
print(f"% within ±1 pt: {(abs(residuals)<=1).mean()*100:.1f}%")
# Out:
# Residual mean : -0.0134  (close to 0 = unbiased)
# Residual std  : 1.2052
# % within ±1 pt: 72.2%

# %% [markdown]
# ## c. Mean Error by Product Category

# %%
import plotly.express as px
import plotly.graph_objects as go

# Attach predictions back to test set for category-level analysis
test_df = X_test.copy()
test_df["actual"] = y_test.values
test_df["predicted"] = y_pred_final
test_df["error"] = test_df["actual"] - test_df["predicted"]
test_df["abs_error"] = test_df["error"].abs()

# Only keep rows where category is known
cat_col = "product_category_name_english"

if cat_col in test_df.columns:

    cat_errors = (
        test_df.groupby(cat_col)
        .agg(
            mean_abs_error=("abs_error", "mean"),
            mean_error=("error", "mean"),
            count=("actual", "count")
        )
        .query("count >= 30")
        .sort_values("mean_abs_error", ascending=False)
    )

    top_n = 20
    plot_df = cat_errors.head(top_n).copy()

    # Create horizontal bar chart
    fig = px.bar(
        plot_df,
        x="mean_abs_error",
        y=plot_df.index,
        orientation="h",
        labels={
            "mean_abs_error": "Mean Absolute Error (rating points)",
            "y": "Product Category"
        },
        title=(
            f"Mean Absolute Error by Product Category "
            f"(Top {top_n} by error, categories with ≥30 test orders)"
        ),
        hover_data={
            "mean_abs_error": ":.3f",
            "mean_error": ":.3f",
            "count": True
        }
    )

    # Reverse y-axis so highest-error category is at the top
    fig.update_yaxes(autorange="reversed")

    # Overall MAE reference line
    fig.add_vline(
        x=mae_final,
        line_dash="dash",
        line_color="red",
        line_width=2,
        annotation_text=f"Overall MAE = {mae_final:.3f}",
        annotation_position="top"
    )

    fig.update_layout(
        template="plotly_white",
        width=1100,
        height=800,
        xaxis_title="Mean Absolute Error (rating points)",
        yaxis_title="Product Category",
        showlegend=False
    )

    fig.show()

    # Top 10 categories with highest prediction error
    print("Top 10 categories with highest prediction error:")
    display(cat_errors.head(10).round(3))

    # Top 10 categories with lowest prediction error
    print("\nTop 10 categories with lowest prediction error:")
    display(
        cat_errors.tail(10)
        .sort_values("mean_abs_error")
        .round(3)
    )

else:
    print(
        f"Column '{cat_col}' not found in test features — "
        "skipping category plot."
    )
# Out:
# /tmp/ipykernel_1844/2607785977.py:17: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   test_df.groupby(cat_col)
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #  Business Insights — What Drives Low Ratings?
#
# The following insights are derived from the engineered features, EDA findings,
# and model behaviour observed throughout the notebook.

# %%
# ── Insight 1: Delivery delay is the single biggest driver of low ratings ──
delayed_mask    = df["is_delayed"] == 1
on_time_mask    = df["is_delayed"] == 0

avg_delayed  = df.loc[delayed_mask,  "rating"].mean() if "rating" in df.columns else df.loc[delayed_mask,  "review_score"].mean()
avg_on_time  = df.loc[on_time_mask,  "rating"].mean() if "rating" in df.columns else df.loc[on_time_mask,  "review_score"].mean()

rating_col = "rating" if "rating" in df.columns else "review_score"

# Corr: delay days vs rating
delay_corr = df[["delivery_delay_days", rating_col]].corr().iloc[0, 1]

# Average rating by delay bucket
delay_buckets = pd.cut(
    df["delivery_delay_days"],
    bins=[-999, -1, 0, 3, 7, 14, 999],
    labels=["Early", "On-time", "1-3d late", "4-7d late", "8-14d late", ">14d late"]
)
bucket_avg = df.groupby(delay_buckets)[rating_col].mean().round(2)

print("=" * 55)
print(" INSIGHT 1: Delivery Delay vs Customer Rating")
print("=" * 55)
print(f"  On-time orders   : avg rating: {avg_on_time:.2f} ")
print(f"  Delayed orders   : avg rating: {avg_delayed:.2f} ")
print(f"  Correlation (delivery_delay_days vs rating): {delay_corr:.3f}")
print(f"\
  Rating by delay bucket:")
for bucket, val in bucket_avg.items():
    print(f"    {str(bucket):<12} -> {val:.2f} ")
print()

# Regression-style slope: 1-unit delay → Δrating
from numpy.polynomial.polynomial import polyfit as np_polyfit
mask = df["delivery_delay_days"].between(-30, 60)
b_d, m_d = np_polyfit(df.loc[mask, "delivery_delay_days"], df.loc[mask, rating_col], 1)
print(f"  Linear slope: each additional day of delay changes rating by {m_d:+.4f} points")
print()
print("  Business Recommendation:")
print("  Delivery delay is the #1 driver of poor customer ratings.")
print("  Orders delayed >3 days should trigger proactive customer communication")
print("  (e.g., automated SMS updates) to manage expectations and soften dissatisfaction.")
print("  Prioritise on-time logistics for high-value orders.")
# Out:
# ...
#  INSIGHT 1: Delivery Delay vs Customer Rating
# ...
#   On-time orders   : avg rating: 4.13
#   Delayed orders   : avg rating: 2.44
#   Correlation (delivery_delay_days vs rating): -0.228
#   Rating by delay bucket:
#     Early        -> 4.21
#     On-time      -> 4.08
#     1-3d late    -> 3.57
#     4-7d late    -> 2.21
#     8-14d late   -> 1.71
#     >14d late    -> 1.72
#
#   Linear slope: each additional day of delay changes rating by -0.0410 points
#
#   Business Recommendation:
#   Delivery delay is the #1 driver of poor customer ratings.
#   Orders delayed >3 days should trigger proactive customer communication
#   (e.g., automated SMS updates) to manage expectations and soften dissatisfaction.
#   Prioritise on-time logistics for high-value orders.
# /tmp/ipykernel_1844/3437737759.py:19: FutureWarning:
#
# ...

# %%
# ── Insight 2: Shipping cost relative to product price hurts satisfaction ──

# Bucket shipping_price_ratio into quartiles
df["spr_bucket"] = pd.qcut(
    df["shipping_price_ratio"].clip(0, 5),  # clip extreme outliers
    q=4,
    labels=["Q1 (cheapest)", "Q2", "Q3", "Q4 (most expensive)"]
)
spr_avg = df.groupby("spr_bucket")[rating_col].mean().round(2)

# Corr
spr_corr = df[["shipping_price_ratio", rating_col]].dropna().corr().iloc[0, 1]

print("=" * 55)
print(" INSIGHT 2: Shipping Cost Ratio vs Customer Rating")
print("=" * 55)
print(f"  Correlation (shipping_price_ratio vs rating): {spr_corr:.3f}")
print(f"  Average rating by shipping-cost quartile:")
for bucket, val in spr_avg.items():
    print(f"    {str(bucket):<22} -> {val:.2f} ")
print()
print("  Customers whose freight cost is high relative to product price")
print("  tend to leave lower ratings — a " "val for money "" perception effect." )
print()
print("  Business Recommendation:")
print("  For orders where freight_value / price > 0.5 (shipping > 50% of product cost),")
print("  consider subsidised shipping thresholds or free-shipping promotions to")
print("  reduce perceived unfairness and improve post-purchase satisfaction.")
# Out:
# ...
#  INSIGHT 2: Shipping Cost Ratio vs Customer Rating
# ...
#   Correlation (shipping_price_ratio vs rating): -0.031
#   Average rating by shipping-cost quartile:
#     Q1 (cheapest)          -> 4.07
#     Q2                     -> 3.99
#     Q3                     -> 4.04
#     Q4 (most expensive)    -> 3.97
#
#   Customers whose freight cost is high relative to product price
#   tend to leave lower ratings — a val for money  perception effect.
#
#   Business Recommendation:
#   For orders where freight_value / price > 0.5 (shipping > 50% of product cost),
#   consider subsidised shipping thresholds or free-shipping promotions to
#   reduce perceived unfairness and improve post-purchase satisfaction.
# /tmp/ipykernel_1844/3150540476.py:9: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.

# %%
# ── Insight 3: Order status is a near-perfect predictor of low ratings ──

status_avg = (
    df.groupby("order_status")[rating_col]
    .agg(["mean", "count"])
    .rename(columns={"mean": "avg_rating", "count": "n_orders"})
    .sort_values("avg_rating")
    .round(2)
)

print("=" * 55)
print(" INSIGHT 3: Order Status vs Customer Rating")
print("=" * 55)
display(status_avg)
print()

delivered_avg = status_avg.loc[status_avg.index.str.contains("delivered"), "avg_rating"].values
if len(delivered_avg):
    print(f"  Delivered orders avg rating   : {delivered_avg[0]:.2f} ")

print()
print("  Orders that are not 'delivered' (e.g. processing, canceled, unavailable)")
print("  average below 2.0 stars — these orders represent operational failures that")
print("  severely damage customer trust.")
print()
print("  Business Recommendation:")
print("  Implement automated escalation: any order remaining in 'processing'")
print("  or 'invoiced' status beyond 48 hours should trigger a seller alert.")
print("  Proactively cancelling hopeless orders with a refund/voucher recovers")
print("  more goodwill than leaving customers waiting.")
# Out:
# ...
#  INSIGHT 3: Order Status vs Customer Rating
# ...
# /tmp/ipykernel_1844/1473524177.py:4: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#               avg_rating  n_orders
# order_status
# processing          1.35       370
# unavailable         1.51       638
# invoiced            1.65       372
# canceled            1.82       730
# shipped             1.98      1168
# approved            2.00         3
# created             2.33         3
# delivered           4.08    114862
#   Delivered orders avg rating   : 4.08
#
#   Orders that are not 'delivered' (e.g. processing, canceled, unavailable)
#   average below 2.0 stars — these orders represent operational failures that
#   severely damage customer trust.
#
#   Business Recommendation:
# ...

# %%
# additional insight
# ── Insight 4 : Product photos correlate with higher ratings ──

photos_avg = (
    df.groupby("product_photos_qty")[rating_col]
    .agg(["mean", "count"])
    .rename(columns={"mean": "avg_rating", "count": "n_orders"})
    .query("n_orders >= 50")
    .round(2)
)

photo_corr = df[["product_photos_qty", rating_col]].dropna().corr().iloc[0, 1]

print("=" * 55)
print(" INSIGHT 4 (Bonus): Product Photos vs Customer Rating")
print("=" * 55)
print(f"  Correlation (product_photos_qty vs rating): {photo_corr:.3f}")
print()
display(photos_avg.head(10))
print()
print("  Products with only 1 photo average a lower rating than those with 5+ photos.")
print("  Better visual information reduces purchase uncertainty and post-purchase regret.")
print()
print("  Business Recommendation:")
print("  Require a minimum of 3 product photos before a listing goes live.")
print("  Sellers with <3 photos should receive an automated nudge and a style guide.")
print("  This is a low-effort, high-impact change that improves customer expectations.")
# Out:
# ...
#  INSIGHT 4 (Bonus): Product Photos vs Customer Rating
# ...
#   Correlation (product_photos_qty vs rating): 0.031
#                     avg_rating  n_orders
# product_photos_qty
# 1.0                       3.96     60950
# 2.0                       4.05     22895
# 3.0                       4.08     12872
# 4.0                       4.04      8778
# 5.0                       4.15      5561
# 6.0                       4.06      3906
# 7.0                       4.11      1552
# 8.0                       4.17       771
# 9.0                       4.06       309
# 10.0                      4.00       353
#   Products with only 1 photo average a lower rating than those with 5+ photos.
#   Better visual information reduces purchase uncertainty and post-purchase regret.
#
#   Business Recommendation:
#   Require a minimum of 3 product photos before a listing goes live.
#   Sellers with <3 photos should receive an automated nudge and a style guide.
# ...

# %%
# ── Insight 5: Payment installments relate to customer rating ──
inst_avg = (
    df.groupby("multiple_installments")[rating_col]
    .agg(["mean", "count"])
    .rename(columns={"mean": "avg_rating", "count": "n_orders"})
    .round(2)
)

print("=" * 55)
print(" INSIGHT 5: Payment Installments vs Customer Rating")
print("=" * 55)
display(inst_avg)
print()
print("### Insight")
print("- **What happened?** Orders paid in multiple installments show a different average "
      "rating than single-installment orders (see table above).")
print("- **ML meaning:** multiple_installments and average_installment_value are kept as "
      "features so the model can capture payment-related satisfaction effects.")
print("- **Business meaning:** Payment structure may add friction (fees, confusion about "
      "total cost) that affects the post-purchase experience.")
print("- **Action / recommendation:** Review checkout clarity and fee transparency for "
      "installment payments; test a clearer 'total cost' summary at checkout.")
print("- **Limitation:** This may be confounded with price — installment payments are more "
      "common on higher-priced items, which could carry their own satisfaction dynamics.")
# Out:
# ...
#  INSIGHT 5: Payment Installments vs Customer Rating
# ...
#                        avg_rating  n_orders
# multiple_installments
# 0                            4.05     59003
# 1                            3.98     59143
# ### Insight
# - **What happened?** Orders paid in multiple installments show a different average rating than single-installment orders (see table above).
# - **ML meaning:** multiple_installments and average_installment_value are kept as features so the model can capture payment-related satisfaction effects.
# - **Business meaning:** Payment structure may add friction (fees, confusion about total cost) that affects the post-purchase experience.
# - **Action / recommendation:** Review checkout clarity and fee transparency for installment payments; test a clearer 'total cost' summary at checkout.
# - **Limitation:** This may be confounded with price — installment payments are more common on higher-priced items, which could carry their own satisfaction dynamics.

# %%
# ── Insight 6: Cross-state shipping is linked to lower ratings ──
state_avg = (
    df.groupby("same_state")[rating_col]
    .agg(["mean", "count"])
    .rename(columns={"mean": "avg_rating", "count": "n_orders"})
    .round(2)
)

print("=" * 55)
print(" INSIGHT 6: Same-State vs Cross-State Shipping")
print("=" * 55)
display(state_avg)
print()
print("### Insight")
print("- **What happened?** Same-state orders and cross-state orders show a gap in average "
      "rating (see table above), consistent with cross-state orders taking longer to arrive.")
print("- **ML meaning:** same_state is kept as a feature alongside delivery_delay_days so the "
      "model can separate the distance effect from the delay effect.")
print("- **Business meaning:** Distance-driven delay is a structural, predictable source of "
      "dissatisfaction rather than a random operational failure.")
print("- **Action / recommendation:** Set more conservative, realistic expected-delivery windows "
      "for cross-state orders, and evaluate regional fulfilment centres to shorten the distance.")
print("- **Limitation:** same_state is a coarse proxy for distance — actual shipping distance "
      "or logistics-zone data would give a more precise picture.")
# Out:
# ...
#  INSIGHT 6: Same-State vs Cross-State Shipping
# ...
#             avg_rating  n_orders
# same_state
# 0                 3.94     75741
# 1                 4.14     42405
# ### Insight
# - **What happened?** Same-state orders and cross-state orders show a gap in average rating (see table above), consistent with cross-state orders taking longer to arrive.
# - **ML meaning:** same_state is kept as a feature alongside delivery_delay_days so the model can separate the distance effect from the delay effect.
# - **Business meaning:** Distance-driven delay is a structural, predictable source of dissatisfaction rather than a random operational failure.
# - **Action / recommendation:** Set more conservative, realistic expected-delivery windows for cross-state orders, and evaluate regional fulfilment centres to shorten the distance.
# - **Limitation:** same_state is a coarse proxy for distance — actual shipping distance or logistics-zone data would give a more precise picture.

# %% [markdown]
# ---
#
# ## 15. Business Recommendations — Summary of Findings
#
# | # | Factor | Impact | Recommendation | Priority |
# |---|--------|--------|-----------------|----------|
# | 1 | **Delivery delay** | Delayed orders avg ~2.5★ vs ~4.1★ on-time; each extra day of delay reduces the predicted rating | Proactive SMS/email updates for delayed orders; prioritise on-time logistics for high-value orders | High |
# | 2 | **High shipping cost ratio** | When freight > 50% of product price, ratings drop noticeably | Introduce free-shipping thresholds or subsidised shipping on low-margin items | High |
# | 3 | **Non-delivered order status** | Processing / canceled / unavailable orders average < 2.0★ | Escalation alerts for stalled orders after 48h; proactive refund + voucher for unresolvable cases | High |
# | 4 | **Few product photos** | Single-photo listings receive lower average ratings | Mandate ≥3 photos per listing; automated seller nudge for non-compliant listings | Medium |
# | 5 | **Multiple installments** | Installment orders show a different average rating than single-payment orders | Review checkout clarity and fee transparency for installment payments | Medium |
# | 6 | **Cross-state shipping** | Cross-state orders average lower ratings than same-state orders | Set realistic delivery windows for cross-state orders; consider regional fulfilment centres | Medium |
#
# **Overall priority order:** fix delivery delay and non-delivered order handling first (biggest, most controllable impact) → then shipping-cost fairness → then product-listing quality and payment/checkout experience.

# %% [markdown]
# ---
#
# ## 16. Limitations
#
# - **Dataset scope:** The Olist dataset covers Brazilian orders from a specific historical period only; conclusions may not generalise to other markets, seasons, or platforms.
# - **No explicit "returns" data:** Unlike the schema in the original brief, this dataset has no return/refund fields, so return-related signals could not be tested as predictors of rating.
# - **Correlation vs. causation:** Several insights (delivery delay, shipping-cost ratio, product photos, installments) are based on group averages/correlations, not a controlled experiment — they show association, not proof of cause.
# - **Imbalanced target:** ~56% of orders receive a 5-star rating, so the model is naturally better at predicting high ratings than distinguishing the less frequent low-rating orders (2-3 stars); MAE/RMSE can look good overall while still missing minority low-rating cases.
# - **Feature timing / leakage:** `has_review_comment` was intentionally excluded from the final feature set — it is generated at the same moment the customer submits the rating, so it would not be available at real prediction time (before the review exists).
# - **Model scope:** Only 4 classical algorithms were compared, per the assignment scope; gradient-boosted models (XGBoost/LightGBM) were not tried and could likely improve MAE/RMSE further.
# - **Hyperparameter search:** GridSearchCV used a small grid (2-3 values per parameter) to keep runtime reasonable — a wider search might find a better configuration.
#
# **What could be improved with more time/data:** add real return/complaint data if available, try gradient-boosted models, and run a time-based (not random) train/test split to check whether the model generalises to *future* orders, since satisfaction patterns can drift over time.

# %% [markdown]
# ---
#
# ## 17. Export
#
# Save the cleaned dataset, the final tuned model, and the model comparison report for the submission ZIP.
# (Key charts were already saved into `visuals/` as they were generated earlier in the notebook.)

# %%
import os

os.makedirs("data", exist_ok=True)
os.makedirs("model", exist_ok=True)
os.makedirs("visuals", exist_ok=True)
os.makedirs("reports", exist_ok=True)

# 1. Cleaned dataset with all derived features
df.to_csv("data/Capstone_Clean_Orders.csv", index=False)
print("Saved: data/Capstone_Clean_Orders.csv", df.shape)

# 2. Final tuned model (full pipeline: preprocessing + regressor)
joblib.dump(tuned_model, "model/best_model.pkl")
print(f"Saved: model/best_model.pkl  ({winner_name}, tuned)")

# 3. Model comparison table
model_comparison_final.to_csv("reports/model_comparison.csv", index=False)
print("Saved: reports/model_comparison.csv")

print()
print("Saved visuals/:")
for fname in sorted(os.listdir("visuals")):
    print(" -", fname)
print()
print("Reminder: Restart & Run All once before zipping, so every file above is regenerated fresh")
print("from the final version of the notebook (per the submission rules).")
# Out:
# Saved: data/Capstone_Clean_Orders.csv (118146, 68)
# Saved: model/best_model.pkl  (Decision Tree, tuned)
# Saved: reports/model_comparison.csv
#
# Saved visuals/:
#  - 01_rating_distribution.png
#  - 02_correlation_heatmap.png
#  - 03_target_distribution.png
#  - 04_predicted_vs_actual.png
#  - 05_residuals.png
#  - 06_feature_importance.png
#
# Reminder: Restart & Run All once before zipping, so every file above is regenerated fresh
# from the final version of the notebook (per the submission rules).
